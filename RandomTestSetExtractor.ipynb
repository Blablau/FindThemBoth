# %%
#EXTRACTOR FOR KERMIT TEST SET
from shutil import copyfile
import random

num_of_frames = 4500
train_test_split_ratio = 0.10

num_of_testframes = int(train_test_split_ratio * num_of_frames)

selected_frame_numbers = random.sample(range(1, num_of_frames), num_of_testframes)

shownumber = 0
for i in range(4500):
    if i in selected_frame_numbers:
        shownumber = 1
        if i <= 1500:
            shownumber = 1
        elif i <= 3000:
            shownumber = 2
        else:
            shownumber = 3
            
        if i % 1500 == 0:
            move('./FolderFrames/AllShows/show' + str(shownumber) + '_' + str(1500) + '.jpg', './FolderFrames/kermitTestSet/show' + str(shownumber) + '_' + str(1500) + '.jpg')
        else:
            move('./FolderFrames/AllShows/show' + str(shownumber) + '_' + str(i%1500) + '.jpg', './FolderFrames/kermitTestSet/show' + str(shownumber) + '_' + str(i%1500) + '.jpg')

# %%
#EXTRACTOR FOR MRS PIGGY TEST SET
from shutil import copyfile, move
import random

num_of_frames = 4500
train_test_split_ratio = 0.10

num_of_testframes = int(train_test_split_ratio * num_of_frames)

selected_frame_numbers = random.sample(range(1, num_of_frames), num_of_testframes)

shownumber = 0
for i in range(4500):
    if i in selected_frame_numbers:
        shownumber = 1
        if i <= 1500:
            shownumber = 1
        elif i <= 3000:
            shownumber = 2
        else:
            shownumber = 3
            
        if i % 1500 == 0:
            move('./FolderFrames/AllShows/show' + str(shownumber) + '_' + str(1500) + '.jpg', './FolderFrames/MrsPiggyTestSet/show' + str(shownumber) + '_' + str(1500) + '.jpg')
        else:
            move('./FolderFrames/AllShows/show' + str(shownumber) + '_' + str(i%1500) + '.jpg', './FolderFrames/MrsPiggyTestSet/show' + str(shownumber) + '_' + str(i%1500) + '.jpg')

# %%
#EXTRACTOR FOR MRS PIGGY TRAIN/VAL SPLIT
#EXTRACTOR FOR MRS PIGGY TEST SET
from shutil import copyfile, move
import random

num_of_frames = 4500
train_test_split_ratio = 0.10

num_of_testframes = int(train_test_split_ratio * num_of_frames)

selected_frame_numbers = random.sample(range(1, num_of_frames), num_of_testframes)

shownumber = 0
for i in range(4500):
    if i in selected_frame_numbers:
        shownumber = 1
        if i <= 1500:
            shownumber = 1
        elif i <= 3000:
            shownumber = 2
        else:
            shownumber = 3
        try:
            if i % 1500 == 0:
                move('./FolderFrames/MrsPiggyDataset/MrsPiggyTrainingSet/NoMrsPiggy/show' + str(shownumber) + '_' + str(1500) + '.jpg', './FolderFrames/MrsPiggyDataset/MrsPiggyValSet/NoMrsPiggy/show' + str(shownumber) + '_' + str(1500) + '.jpg')
            else:
                move('./FolderFrames/MrsPiggyDataset/MrsPiggyTrainingSet/NoMrsPiggy/show' + str(shownumber) + '_' + str(i%1500) + '.jpg', './FolderFrames/MrsPiggyDataset/MrsPiggyValSet/NoMrsPiggy/show' + str(shownumber) + '_' + str(i%1500) + '.jpg')
        except:
            print("polola")
# Out:
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
# polola
